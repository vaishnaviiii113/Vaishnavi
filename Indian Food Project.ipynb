# %% [markdown]
# # Indian Food

# %%
#Importing important libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#Reading the dataset

df = pd.read_csv("indian_food.csv")

# %%
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
#Checking the head of data

df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
#Checking the tail of data

df.tail()
# Out:
#           name                                        ingredients        diet  \
# 250  Til Pitha            Glutinous rice, black sesame seeds, gur  vegetarian
# 251    Bebinca  Coconut milk, egg yolks, clarified butter, all...  vegetarian
# 252     Shufta  Cottage cheese, dry dates, dried rose petals, ...  vegetarian
# 253  Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...  vegetarian
# 254     Pinaca  Brown rice, fennel seeds, grated coconut, blac...  vegetarian
#
#      prep_time  cook_time flavor_profile   course            state      region
# 250          5         30          sweet  dessert            Assam  North East
# 251         20         60          sweet  dessert              Goa        West
# 252         -1         -1          sweet  dessert  Jammu & Kashmir       North
# 253         20         45          sweet  dessert   Madhya Pradesh     Central
# 254         -1         -1          sweet  dessert              Goa        West

# %%
#Replacing all the -1 values in the categorical and numerical columns with nan 
df= df.replace('-1',np.nan)
df = df.replace(-1,np.nan)
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
#ValueCounts

# %%
df["diet"].value_counts()
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %% [raw]
# From these we get to know that 226 dishes are vegetarian and 29 dishes are non vegetarian

# %%
df["course"].value_counts()
# Out:
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: course, dtype: int64

# %% [raw]
# Main course are more than other and starters are very less.

# %%
df["flavor_profile"].value_counts()
# Out:
# spicy     133
# sweet      88
# bitter      4
# sour        1
# Name: flavor_profile, dtype: int64

# %% [raw]
# More Spicy dishes are available

# %%
df["state"].value_counts()
# Out:
# Gujarat            35
# Punjab             32
# Maharashtra        30
# West Bengal        24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Kerala              8
# Odisha              7
# Karnataka           6
# Rajasthan           6
# Telangana           5
# Bihar               3
# Goa                 3
# Manipur             2
# Jammu & Kashmir     2
# Madhya Pradesh      2
# Uttarakhand         1
# Tripura             1
# Nagaland            1
# NCT of Delhi        1
# Chhattisgarh        1
# Haryana             1
# Name: state, dtype: int64

# %% [raw]
# From this we can see Gujarat have more varieties of Dishes

# %%
#Checking the head of categorical variables
df.select_dtypes('object').head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet flavor_profile   course        state region
# 0  vegetarian          sweet  dessert  West Bengal   East
# 1  vegetarian          sweet  dessert    Rajasthan   West
# 2  vegetarian          sweet  dessert       Punjab  North
# 3  vegetarian          sweet  dessert    Rajasthan   West
# 4  vegetarian          sweet  dessert  West Bengal   East

# %% [raw]
# Now we are going to check the number of Veg & Non-Veg Food Dishes

# %%
df["diet"].value_counts()
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %% [raw]
# As we can see Vegetarian Dishes are present more in number

# %% [markdown]
# # Now I'm going to use pie chart for veg & non veg food distirbution

# %%
plt.subplot(1,2,2)
x = df['diet'].value_counts()
explode = [0.1,0]
labels = ['Veg','Non-veg']
plt.pie(x,explode=explode,labels=labels, autopct = '%.2f%%')
plt.title("Pie Chart showing the distribution of Veg/Non-Veg")
plt.legend(labels)
plt.show()

# %% [raw]
# From this we get to know that there are 88.63% of Vegetarian dishes and 11% Non Vegetarian

# %% [markdown]
# # Now we are going to check the count of different flavoured dishes

# %%
#Count plot of different flavours of dishes
sns.countplot(df['flavor_profile'])
plt.title("Count Plot of flavours")
# Out:
# Text(0.5, 1.0, 'Count Plot of flavours')

# %% [raw]
# 1) We can see maximun number of spicy flavoured dishes.

# %% [raw]
# 2)Bitter and Sour are very less in number compared to sweet and spicy

# %% [markdown]
# # Now we are going to check the different courses of meal, starter, main course,snacks and dessert present in table

# %%
sns.countplot(df['course'])
plt.title("Count Plot of course")
# Out:
# Text(0.5, 1.0, 'Count Plot of course')

# %% [raw]
# From here we can see that:

# %% [raw]
# 1) Maximum number of main courses are present.

# %% [raw]
# 2)Lowest number of starters

# %% [markdown]
# # Count Plot of States

# %%
sns.countplot(df['state'])
plt.title("Count Plot of state")
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# From the graph we get to know that, maximum numbers of dishes are from Gujarat, Punjab and Maharashtra

# %% [markdown]
# # TOP 6 STATES WITH MAXIMUM NUMBER OF DISHES.

# %%
a = df['state'].value_counts().reset_index()
a.sort_values(by='state',ascending=False).head(6)
# Out:
#          index  state
# 0      Gujarat     35
# 1       Punjab     32
# 2  Maharashtra     30
# 3  West Bengal     24
# 4        Assam     21
# 5   Tamil Nadu     20

# %% [markdown]
# # Number of Dishes Region Wise

# %%
sns.countplot(df['region'])
plt.title("Count Plot of region")
# Out:
# Text(0.5, 1.0, 'Count Plot of region')

# %% [raw]
# WEST region have maximum number of dishes

# %% [markdown]
# # Count of Veg / Nonveg based on flavor

# %%
plt.figure(figsize=(8,8))
sns.countplot(df['diet'],hue=df['flavor_profile'])
plt.title("Count of Veg/Non-Veg based on flavor")
plt.show()

# %% [raw]
# Non veg we get in spicy flavour whereas Veg we get in all flavours

# %%
pd.crosstab(df['flavor_profile'],df['course'])
# Out:
# course          dessert  main course  snack  starter
# flavor_profile
# bitter                0            3      1        0
# sour                  0            1      0        0
# spicy                 0           96     35        2
# sweet                85            3      0        0

# %% [markdown]
# From this we get that:
# There are 3 dishes in sweet but does not count in desserts.
# In main course, 1 sour flavoured dish.
# We have 2 spicy starter dishes.
# Main course dishes comes in all four flavours.

# %% [markdown]
# #

# %%
pd.crosstab(df['course'],df['diet'])
# Out:
# diet         non vegetarian  vegetarian
# course
# dessert                   0          85
# main course              27         102
# snack                     0          39
# starter                   2           0

# %% [markdown]
# Two Non veg starter dishes.
# Snacks and Desserts are Veg.
# Main courses have both Veg & Non veg.

# %%
df[['course','prep_time']].sort_values(by='prep_time',ascending=False).reset_index().head()
# Out:
#    index       course  prep_time
# 0    114  main course      500.0
# 1    155  main course      495.0
# 2     29      dessert      480.0
# 3    130        snack      360.0
# 4    128        snack      360.0

# %% [markdown]
# From this we get to know that main course takes highest time for preparation

# %% [raw]
# Plotting graph:

# %%
x= df[['flavor_profile','prep_time']].groupby(['flavor_profile']).agg(['max','mean','min'])
x.plot(kind='line')
plt.legend()
plt.show()

# %% [raw]
# We can observe that the Spicy Dishes takes more time for prepartion and Sour Dishes takes less

# %% [markdown]
# Now we are going to add cook time and prep time to find the total time needed to serve a dish

# %%
df['total_time'] = df['prep_time']+df['cook_time']

df.loc[df.groupby(['course'])['total_time'].idxmax()][['total_time','course']]
# Out:
#      total_time       course
# 62        730.0      dessert
# 114       620.0  main course
# 128       450.0        snack
# 123       270.0      starter

# %% [raw]
# Ploting Graph:

# %%
df[['total_time','course']].groupby(['course']).agg(['max','min']).plot(kind='bar', color=['brown','green'])
plt.title("Time taken to be served", fontsize=20)
plt.ylabel("Time",fontsize=15)
plt.show()

# %%
pd.crosstab(df['region'], df['diet'])
# Out:
# diet        non vegetarian  vegetarian
# region
# Central                  0           3
# East                     5          26
# North                    5          44
# North East              13          12
# South                    3          56
# West                     3          71

# %% [markdown]
# We can see that:Central Region have no non veg dishes.
# North East Region have almost same number of veg and non veg dishes.
# West Region have highest number of Veg dishes.

# %% [raw]
# Number of Veg and Non veg dishes in different states of the country.

# %%
pd.crosstab(df['state'], df['diet'])
# Out:
# diet             non vegetarian  vegetarian
# state
# Andhra Pradesh                0          10
# Assam                        10          11
# Bihar                         0           3
# Chhattisgarh                  0           1
# Goa                           1           2
# Gujarat                       0          35
# Haryana                       0           1
# Jammu & Kashmir               0           2
# Karnataka                     0           6
# Kerala                        1           7
# Madhya Pradesh                0           2
# Maharashtra                   2          28
# Manipur                       1           1
# NCT of Delhi                  1           0
# Nagaland                      1           0
# Odisha                        0           7
# Punjab                        4          28
# Rajasthan                     0           6
# Tamil Nadu                    1          19
# Telangana                     1           4
# ...

# %%
pd.crosstab(df['state'], df['diet']).plot(kind ="line")
plt.show()

# %%
#We can get State with its dishes and for that we define a function:

# %%
def state_dish(x):
    return df[df['state']==x][['name','diet','flavor_profile']]

# %%
state_dish("Gujarat")
# Out:
#                           name        diet flavor_profile
# 56                     Basundi  vegetarian          sweet
# 58                    Doodhpak  vegetarian          sweet
# 168                      Saath  vegetarian          spicy
# 169             Bajri no rotlo  vegetarian          spicy
# 174                     Chevdo  vegetarian          spicy
# 175                  Chorafali  vegetarian          spicy
# 176                 Copra paak  vegetarian            NaN
# 177                Daal Dhokli  vegetarian          spicy
# 178              Kutchi dabeli  vegetarian          spicy
# 181                     Dhokla  vegetarian          spicy
# 182                Dudhi halwa  vegetarian          sweet
# 184                  Gud papdi  vegetarian          sweet
# 185                   Ghooghra  vegetarian          spicy
# 186                     Handwo  vegetarian          spicy
# 187                   Halvasan  vegetarian          sweet
# ...

# %%
state_dish("Maharashtra")
# Out:
#                   name            diet flavor_profile
# 16              Sheera      vegetarian          sweet
# 19         Sohan papdi      vegetarian          sweet
# 39              Chikki      vegetarian          sweet
# 55              Anarsa      vegetarian          sweet
# 57             Dhondas      vegetarian          sweet
# 59         Mahim halwa      vegetarian          sweet
# 60               Modak      vegetarian          sweet
# 61         Shankarpali      vegetarian          sweet
# 62           Shrikhand      vegetarian          sweet
# 63          Sutar feni      vegetarian          sweet
# 78             Chapati      vegetarian            NaN
# 88                Poha      vegetarian          spicy
# 165               Amti      vegetarian          spicy
# 166              Zunka      vegetarian          spicy
# 167        Kolim Jawla  non vegetarian          spicy
# 170       Coconut vadi      vegetarian          sweet
# ...

# %%
state_dish("Odisha")
# Out:
#               name        diet flavor_profile
# 14          Phirni  vegetarian          sweet
# 20   Chhena jalebi  vegetarian          sweet
# 21   Chhena kheeri  vegetarian          sweet
# 22     Chhena poda  vegetarian          sweet
# 24     Kheer sagar  vegetarian          sweet
# 32        Rasabali  vegetarian          sweet
# 244        Pakhala  vegetarian            NaN

# %%
#We can get Region with its dishes and for that we define a function:

# %%
def region_dish(x):
    return df[df['region']==x][['name','diet','flavor_profile','state']]

# %%
region_dish('Central')
# Out:
#           name        diet flavor_profile           state
# 89        Fara  vegetarian          spicy    Chhattisgarh
# 194     Laapsi  vegetarian          spicy  Madhya Pradesh
# 253  Mawa Bati  vegetarian          sweet  Madhya Pradesh

# %%
region_dish('West')
# Out:
#                           name        diet flavor_profile        state
# 1                       Boondi  vegetarian          sweet    Rajasthan
# 3                       Ghevar  vegetarian          sweet    Rajasthan
# 16                      Sheera  vegetarian          sweet  Maharashtra
# 19                 Sohan papdi  vegetarian          sweet  Maharashtra
# 39                      Chikki  vegetarian          sweet  Maharashtra
# ..                         ...         ...            ...          ...
# 217                     Khaman  vegetarian          spicy      Gujarat
# 218  Turiya Patra Vatana sabji  vegetarian          spicy      Gujarat
# 219               Churma Ladoo  vegetarian          sweet    Rajasthan
# 251                    Bebinca  vegetarian          sweet          Goa
# 254                     Pinaca  vegetarian          sweet          Goa
#
# [74 rows x 4 columns]

# %%
region_dish('North East')
# Out:
#                name            diet flavor_profile     state
# 26         Lyangcha      vegetarian          sweet     Assam
# 31            Pithe      vegetarian          sweet     Assam
# 64       Maach Jhol  non vegetarian          spicy     Assam
# 65      Pork Bharta  non vegetarian          spicy   Tripura
# 66   Chak Hao Kheer      vegetarian          sweet   Manipur
# 67            Galho  non vegetarian          spicy  Nagaland
# 221    Gheela Pitha      vegetarian          sweet     Assam
# 222            Khar      vegetarian            NaN     Assam
# 223     Kumol Sawul  non vegetarian          spicy     Assam
# 225      Alu Pitika  non vegetarian          spicy     Assam
# 226     Masor tenga  non vegetarian          spicy     Assam
# 227  Bengena Pitika      vegetarian            NaN     Assam
# 228     Bilahi Maas  non vegetarian            NaN     Assam
# 229      Black rice  non vegetarian            NaN   Manipur
# ...

# %% [markdown]
# #

# %% [markdown]
# # CONCLUSION:

# %% [markdown]
# From the above analysis, I can concluded that,
# Gujarat, Maharashta And Punjab have large number of dishes.
# Vegetarian Dishes(88.63%) are more in number than Non Vegetarian(11.73%)
# As we know Indian Food is known for its spicy flavours, that's why spicy dishes are present in large quantity than other flavours like sweet, sour,etc.
# Main course are present more than starter, snacks & desserts.
# If we see Region wise, West region have more Dishes.
# Dessert requires more time to prepare and serve than others(main course, snacks, starters).

# %% [markdown]
# #

# %% [markdown]
# # RESULT:

# %% [markdown]
# From my analysis, i predict that,
# Vegetarian food will be more popular than non vegetarian. As we can see demand for vegetarian dishes is more.
# Requirements for spicy food will be greater than other flavours(sour and bitter).
# Bitter and Sour flavoured food will less needed compared to sweet and spicy.
# Main course will have more demand than others i.e starters, dessert, snacks.
